# %%
import numpy as np
import matplotlib.pyplot as plt
from FuncAnalysis import FuncAnalysis

# %%
def f(x):
    return np.sin(x)

# %%
func_analyse = FuncAnalysis(f)

# %%
x = func_analyse.get_points(0, 10, 50, 0.1)
y = f(x)

# %%
x_ref = np.arange(0, 10, 0.01)
y_ref = f(x_ref)

# %%
x
# Out:
# array([ 0.     ,  0.3125 ,  0.46875,  0.625  ,  0.78125,  0.9375 ,
#         1.09375,  1.25   ,  1.40625,  1.5625 ,  1.71875,  1.875  ,
#         2.03125,  2.1875 ,  2.34375,  2.5    ,  2.65625,  2.8125 ,
#         2.96875,  3.125  ,  3.4375 ,  3.59375,  3.75   ,  3.90625,
#         4.0625 ,  4.21875,  4.375  ,  4.53125,  4.6875 ,  4.84375,
#         5.     ,  5.15625,  5.3125 ,  5.46875,  5.625  ,  5.78125,
#         5.9375 ,  6.09375,  6.25   ,  6.5625 ,  6.71875,  6.875  ,
#         7.03125,  7.1875 ,  7.34375,  7.5    ,  7.65625,  7.8125 ,
#         7.96875,  8.125  ,  8.28125,  8.4375 ,  8.59375,  8.75   ,
#         8.90625,  9.0625 ,  9.21875,  9.375  , 10.     ])

# %%
plt.plot(x_ref, y_ref)
plt.scatter(x, y, c='red')
